# %% [markdown]
# The following cell is the modifed cell, where I used @jit "a decorator from Numba" to compile Python code to machine code for faster execution.
#
# The original timing is 0.8582 seconds; and the new timing for the cell is 0.7699 seconds.

# %%
# Import required modules
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup
import time
from numba import jit

# Path to your XML file
xml_file_path = r'C:\Users\boa\Desktop\xml_containing_html.xml'

# Step 1: Extract HTML content from XML
def extract_html_from_xml(xml_content):
    start_time = time.time()  # Start timing
    
    # Parse the XML content
    root = ET.fromstring(xml_content)
    
    # List to store extracted HTML content
    html_pages = []
    
    # Iterate over all <content> elements in the XML
    for content in root.findall('.//content'):
        html_string = content.text.strip() if content.text else ""
        html_pages.append(html_string)
    
    end_time = time.time()  # End timing
    print(f"Time taken to extract HTML from XML: {end_time - start_time:.4f} seconds")
    
    return html_pages

# Step 2: Optimize link counting function with numba
@jit(nopython=True)
def count_links(link_texts):
    return len(link_texts)

# Step 3: Parse HTML content and count links
def parse_html_and_count_links(html_pages):
    for index, html in enumerate(html_pages):
        start_time = time.time()  # Start timing for each HTML page

        soup = BeautifulSoup(html, 'html.parser')
        
        # Extract the title (if available)
        title = soup.title.string if soup.title else "No title found"
        
        # Find all <a> tags (links)
        links = soup.find_all('a')
        num_links = count_links([link.get('href') for link in links])  # Use numba-optimized count

        # Print out the title and number of links
        print(f"HTML Page {index + 1}:")
        print(f"Title: {title}")
        print(f"Number of links: {num_links}")
        
        # Print all the links found
        for i, link in enumerate(links, 1):
            print(f"  Link {i}: {link.get('href')} -> {link.text}")
        
        end_time = time.time()  # End timing for each HTML page
        print(f"Time taken to parse HTML Page {index + 1}: {end_time - start_time:.4f} seconds\n")

# Main execution
# Read the XML file
with open(xml_file_path, 'r', encoding='utf-8') as file:
    xml_content = file.read()

# Measure time for the entire process
start_time_total = time.time()

# Extract HTML content from the XML
html_pages = extract_html_from_xml(xml_content)

# Parse HTML content and count links
parse_html_and_count_links(html_pages)

# End time for the entire process
end_time_total = time.time()
print(f"Total time taken for the entire process: {end_time_total - start_time_total:.4f} seconds")
# Out:
# Time taken to extract HTML from XML: 0.0100 seconds
# HTML Page 1:
# Title: observations on the role of IT trainer
# Number of links: 5
#   Link 1: https://www.munoz-peterson.com/ -> to
#   Link 2: https://www.munoz-peterson.com/ -> to
#   Link 3: https://richardson.net/ -> fact.
#   Link 4: https://smith.com/ -> of
#   Link 5: https://smith.com/ -> of
# Time taken to parse HTML Page 1: 0.4732 seconds
#
# HTML Page 2:
# Title: observations on the role of Waste management officer
# Number of links: 5
#   Link 1: http://carter.net/ -> the
#   Link 2: http://carter.net/ -> the
#   Link 3: http://huff-hudson.com/ -> to
#   Link 4: http://huff-hudson.com/ -> to
#   Link 5: https://fuentes.net/ -> forms
# Time taken to parse HTML Page 2: 0.0050 seconds
#
# HTML Page 3:
# Title: observations on the role of Data processing manager
# Number of links: 4
#   Link 1: https://avila-thompson.com/ -> quite
#   Link 2: https://avila-thompson.com/ -> quite
#   Link 3: https://copeland.org/ -> selectional
#   Link 4: http://www.grant-williamson.com/ -> For
# Time taken to parse HTML Page 3: 0.0050 seconds
#
# HTML Page 4:
# Title: observations on the role of Designer, fashion/clothing
# Number of links: 5
#   Link 1: https://james.com/ -> a
#   Link 2: https://james.com/ -> a
#   Link 3: http://www.mathews-moore.com/ -> sets
#   Link 4: https://carter-powers.net/ -> of
#   Link 5: https://carter-powers.net/ -> of
# Time taken to parse HTML Page 4: 0.0030 seconds
#
# HTML Page 5:
# Title: observations on the role of Secretary, company
# Number of links: 5
#   Link 1: https://miller-grant.info/ -> the
#   Link 2: https://miller-grant.info/ -> the
#   Link 3: https://phillips-harris.com/ -> in
#   Link 4: https://phillips-harris.com/ -> in
#   Link 5: http://perez.info/ -> constructions
# Time taken to parse HTML Page 5: 0.0050 seconds
#
# HTML Page 6:
# Title: observations on the role of Production assistant, radio
# Number of links: 4
#   Link 1: http://www.cook.com/ -> property
#   Link 2: http://www.wilson-navarro.com/ -> C1,
#   Link 3: https://www.young-davis.info/ -> that
#   Link 4: https://www.young-davis.info/ -> that
# Time taken to parse HTML Page 6: 0.0040 seconds
#
# HTML Page 7:
# Title: observations on the role of Bonds trader
# Number of links: 4
#   Link 1: http://weber-collins.com/ -> virtual
# gibberish
#   Link 2: http://vang.org/ -> consequence
#   Link 3: http://fuller.com/ -> be
#   Link 4: http://fuller.com/ -> be
# Time taken to parse HTML Page 7: 0.0040 seconds
#
# HTML Page 8:
# Title: observations on the role of Conservation officer, historic buildings
# Number of links: 3
#   Link 1: https://www.lee-blackburn.com/ -> English
#   Link 2: http://www.jordan.com/ -> case
#   Link 3: http://www.marshall.com/ -> suggested
# Time taken to parse HTML Page 8: 0.0080 seconds
#
# HTML Page 9:
# Title: observations on the role of Secondary school teacher
# Number of links: 3
#   Link 1: https://www.bass.biz/ -> defined
#   Link 2: https://fowler.biz/ -> fundamental
# error
#   Link 3: http://estes.com/ -> language
# Time taken to parse HTML Page 9: 0.0050 seconds
#
# HTML Page 10:
# Title: observations on the role of Psychiatric nurse
# Number of links: 4
#   Link 1: http://stevenson.com/ -> supporting
#   Link 2: http://hall-foley.com/ -> the
# dominance
#   Link 3: https://www.crosby.biz/ -> is
#   Link 4: https://www.crosby.biz/ -> is
# Time taken to parse HTML Page 10: 0.0070 seconds
#
# HTML Page 11:
# Title: observations on the role of Engineer, civil (contracting)
# Number of links: 6
#   Link 1: http://hernandez.com/ -> not
#   Link 2: http://hernandez.com/ -> not
#   Link 3: http://www.holden.info/ -> of
#   Link 4: http://www.holden.info/ -> of
#   Link 5: http://www.ross.biz/ -> not
#   Link 6: http://www.ross.biz/ -> not
# Time taken to parse HTML Page 11: 0.0030 seconds
#
# HTML Page 12:
# Title: observations on the role of Presenter, broadcasting
# Number of links: 3
#   Link 1: http://www.chavez-bryant.com/ -> Note
#   Link 2: https://wilson-miller.com/ -> general
#   Link 3: http://www.bennett-murray.biz/ -> Summarizing,
# Time taken to parse HTML Page 12: 0.0021 seconds
#
# HTML Page 13:
# Title: observations on the role of Archivist
# Number of links: 5
#   Link 1: https://www.harrison.com/ -> utterance
#   Link 2: https://www.harrison.com/ -> utterance
#   Link 3: http://www.scott.com/ -> interesting
#   Link 4: https://www.payne.com/ -> in
#   Link 5: https://www.payne.com/ -> in
# Time taken to parse HTML Page 13: 0.0030 seconds
#
# HTML Page 14:
# Title: observations on the role of Proofreader
# Number of links: 5
#   Link 1: https://www.hansen-flores.com/ -> appearance
#   Link 2: https://www.vazquez-jones.com/ -> a
#   Link 3: https://www.vazquez-jones.com/ -> a
#   Link 4: http://conway.com/ -> the
#   Link 5: http://conway.com/ -> the
# Time taken to parse HTML Page 14: 0.0010 seconds
#
# HTML Page 15:
# Title: observations on the role of Telecommunications researcher
# Number of links: 4
#   Link 1: https://www.cruz.com/ -> these
#   Link 2: http://rojas.net/ -> gap
#   Link 3: http://rojas.net/ -> gap
#   Link 4: http://boyd.com/ -> unspecified
# Time taken to parse HTML Page 15: 0.0020 seconds
#
# HTML Page 16:
# Title: observations on the role of Retail banker
# Number of links: 4
#   Link 1: https://www.scott.biz/ -> as
#   Link 2: https://www.scott.biz/ -> as
#   Link 3: https://harmon-thomas.org/ -> discussed
#   Link 4: http://smith-miller.com/ -> sufficiently
# Time taken to parse HTML Page 16: 0.0020 seconds
#
# HTML Page 17:
# Title: observations on the role of Doctor, general practice
# Number of links: 5
#   Link 1: https://www.miller.info/ -> system
#   Link 2: http://www.oconnell.biz/ -> to
#   Link 3: http://www.oconnell.biz/ -> to
#   Link 4: http://www.osborne.com/ -> of
#   Link 5: http://www.osborne.com/ -> of
# Time taken to parse HTML Page 17: 0.0011 seconds
#
# HTML Page 18:
# Title: observations on the role of Science writer
# Number of links: 5
#   Link 1: http://www.thomas.com/ -> with
#   Link 2: http://www.thomas.com/ -> with
#   Link 3: http://www.nelson.org/ -> constructions
#   Link 4: http://www.jones.net/ -> the
#   Link 5: http://www.jones.net/ -> the
# Time taken to parse HTML Page 18: 0.0020 seconds
#
# HTML Page 19:
# Title: observations on the role of Landscape architect
# Number of links: 3
#   Link 1: https://anderson.biz/ -> must
#   Link 2: http://www.becker-kelly.com/ -> serious
#   Link 3: http://www.meadows.org/ -> phonemic
# Time taken to parse HTML Page 19: 0.0030 seconds
#
# HTML Page 20:
# Title: observations on the role of Diagnostic radiographer
# Number of links: 3
#   Link 1: https://lee.com/ -> (99c)
#   Link 2: https://smith.net/ -> abstract
#   Link 3: https://mitchell.com/ -> base
# Time taken to parse HTML Page 20: 0.0020 seconds
#
# HTML Page 21:
# Title: observations on the role of Warehouse manager
# Number of links: 4
#   Link 1: https://campbell-sullivan.com/ -> stipulation
#   Link 2: http://hernandez-dean.com/ -> element
# suffices
#   Link 3: https://alexander-martinez.net/ -> of
#   Link 4: https://alexander-martinez.net/ -> of
# Time taken to parse HTML Page 21: 0.0020 seconds
#
# HTML Page 22:
# Title: observations on the role of Administrator, education
# Number of links: 3
#   Link 1: http://walter-jacobs.org/ -> level
#   Link 2: https://www.dunn.com/ -> which
# conformity
#   Link 3: https://lopez-bean.com/ -> of
# the
# Time taken to parse HTML Page 22: 0.0020 seconds
#
# HTML Page 23:
# Title: observations on the role of Biomedical scientist
# Number of links: 3
#   Link 1: http://www.baird.net/ -> utterance
# test.
#   Link 2: https://martinez.org/ -> sense
#   Link 3: http://davenport.com/ -> diversified
# Time taken to parse HTML Page 23: 0.0020 seconds
#
# HTML Page 24:
# Title: observations on the role of Occupational psychologist
# Number of links: 4
#   Link 1: http://rivas.com/ -> structure
#   Link 2: http://cox.com/ -> delimits
#   Link 3: http://williams-parker.net/ -> of
#   Link 4: http://williams-parker.net/ -> of
# Time taken to parse HTML Page 24: 0.0010 seconds
#
# HTML Page 25:
# Title: observations on the role of Therapist, art
# Number of links: 4
#   Link 1: https://www.walsh.org/ -> be
#   Link 2: https://www.walsh.org/ -> be
#   Link 3: http://www.anderson.com/ -> earlier
#   Link 4: http://fuller.com/ -> case
# Time taken to parse HTML Page 25: 0.0020 seconds
#
# HTML Page 26:
# Title: observations on the role of Meteorologist
# Number of links: 3
#   Link 1: http://www.gilmore.com/ -> Let
# us
#   Link 2: http://www.fernandez.biz/ -> English
# sentences
#   Link 3: https://wiggins-garrett.org/ -> subject
# Time taken to parse HTML Page 26: 0.0020 seconds
#
# HTML Page 27:
# Title: observations on the role of Designer, ceramics/pottery
# Number of links: 5
#   Link 1: http://www.sims.com/ -> grammar.
#   Link 2: https://short.com/ -> the
#   Link 3: https://short.com/ -> the
#   Link 4: https://sanchez-walker.info/ -> a
#   Link 5: https://sanchez-walker.info/ -> a
# Time taken to parse HTML Page 27: 0.0010 seconds
#
# HTML Page 28:
# Title: observations on the role of Surveyor, building control
# Number of links: 4
#   Link 1: https://www.conway-campbell.com/ -> of
#   Link 2: https://www.conway-campbell.com/ -> of
#   Link 3: https://www.davies.com/ -> seen
#   Link 4: https://ward.com/ -> a
# descriptive
# Time taken to parse HTML Page 28: 0.0020 seconds
#
# HTML Page 29:
# Title: observations on the role of Engineer, site
# Number of links: 4
#   Link 1: https://www.reynolds-gonzalez.com/ -> adjunctions
#   Link 2: https://clark.com/ -> of
#   Link 3: https://clark.com/ -> of
#   Link 4: https://www.ayala.com/ -> domains
# Time taken to parse HTML Page 29: 0.0010 seconds
#
# HTML Page 30:
# Title: observations on the role of Prison officer
# Number of links: 3
#   Link 1: https://www.salazar.info/ -> discussion
#   Link 2: http://www.smith-sutton.com/ -> for
#   Link 3: https://barnes.com/ -> (97),
# Time taken to parse HTML Page 30: 0.0030 seconds
#
# HTML Page 31:
# Title: observations on the role of Research officer, trade union
# Number of links: 3
#   Link 1: https://lane.info/ -> follows
#   Link 2: http://www.anthony.org/ -> of
# utterance
#   Link 3: https://chang.org/ -> about
# Time taken to parse HTML Page 31: 0.0010 seconds
#
# HTML Page 32:
# Title: observations on the role of Teacher, music
# Number of links: 5
#   Link 1: http://www.leach.com/ -> is
#   Link 2: http://www.leach.com/ -> is
#   Link 3: http://ramos-peters.biz/ -> systematic
#   Link 4: https://bell-houston.com/ -> of
#   Link 5: https://bell-houston.com/ -> of
# Time taken to parse HTML Page 32: 0.0020 seconds
#
# HTML Page 33:
# Title: observations on the role of Science writer
# Number of links: 4
#   Link 1: https://gates.net/ -> the
#   Link 2: https://gates.net/ -> the
#   Link 3: http://www.pierce-wood.com/ -> resumptive
#   Link 4: http://www.waters-martin.com/ -> (98d)).
# Time taken to parse HTML Page 33: 0.0010 seconds
#
# HTML Page 34:
# Title: observations on the role of Engineer, land
# Number of links: 3
#   Link 1: https://www.snyder.net/ -> outlined
#   Link 2: http://www.collins-hutchinson.org/ -> any
# associated
#   Link 3: https://vasquez.org/ -> proposed
# Time taken to parse HTML Page 34: 0.0020 seconds
#
# HTML Page 35:
# Title: observations on the role of Designer, industrial/product
# Number of links: 5
#   Link 1: https://www.solis.org/ -> of
#   Link 2: https://www.solis.org/ -> of
#   Link 3: http://webb.com/ -> delimits
#   Link 4: http://campbell-parsons.com/ -> is
#   Link 5: http://campbell-parsons.com/ -> is
# Time taken to parse HTML Page 35: 0.0010 seconds
#
# HTML Page 36:
# Title: observations on the role of Market researcher
# Number of links: 5
#   Link 1: http://www.macdonald-barber.biz/ -> this
#   Link 2: http://www.morgan.com/ -> a
#   Link 3: http://www.morgan.com/ -> a
#   Link 4: https://black-williams.com/ -> of
#   Link 5: https://black-williams.com/ -> of
# Time taken to parse HTML Page 36: 0.0020 seconds
#
# HTML Page 37:
# Title: observations on the role of English as a foreign language teacher
# Number of links: 4
#   Link 1: http://www.contreras.org/ -> the
#   Link 2: http://www.contreras.org/ -> the
#   Link 3: http://www.payne-chan.com/ -> phonemic
#   Link 4: http://harrell.net/ -> component
# Time taken to parse HTML Page 37: 0.0010 seconds
#
# HTML Page 38:
# Title: observations on the role of Financial planner
# Number of links: 5
#   Link 1: http://www.mosley-jones.com/ -> EC
#   Link 2: http://www.saunders.com/ -> as
#   Link 3: http://www.saunders.com/ -> as
#   Link 4: https://jones-jones.biz/ -> in
#   Link 5: https://jones-jones.biz/ -> in
# Time taken to parse HTML Page 38: 0.0020 seconds
#
# HTML Page 39:
# Title: observations on the role of Chartered legal executive (England and Wales)
# Number of links: 4
#   Link 1: https://www.thompson-nelson.info/ -> gap
#   Link 2: https://www.green-reynolds.com/ -> not
#   Link 3: https://www.green-reynolds.com/ -> not
#   Link 4: http://jenkins.info/ -> error
# Time taken to parse HTML Page 39: 0.0011 seconds
#
# HTML Page 40:
# Title: observations on the role of Make
# Number of links: 4
#   Link 1: https://daniels-chang.com/ -> account
#   Link 2: https://www.olson.com/ -> be
#   Link 3: https://www.olson.com/ -> be
#   Link 4: https://www.henderson.biz/ -> Notice,
# Time taken to parse HTML Page 40: 0.0030 seconds
#
# HTML Page 41:
# Title: observations on the role of Counsellor
# Number of links: 4
#   Link 1: http://cunningham.biz/ -> of
#   Link 2: http://cunningham.biz/ -> of
#   Link 3: https://www.harper.com/ -> adequate
#   Link 4: https://www.lawson.com/ -> far,
# Time taken to parse HTML Page 41: 0.0010 seconds
#
# HTML Page 42:
# Title: observations on the role of Call centre manager
# Number of links: 3
#   Link 1: https://conley.biz/ -> levels
#   Link 2: http://www.spencer-wilson.info/ -> semigrammaticalness
#   Link 3: https://www.berry.com/ -> delimits
# Time taken to parse HTML Page 42: 0.0020 seconds
#
# HTML Page 43:
# Title: observations on the role of Psychologist, counselling
# Number of links: 6
#   Link 1: http://roberson.info/ -> is
#   Link 2: http://roberson.info/ -> is
#   Link 3: http://powell.net/ -> the
#   Link 4: http://powell.net/ -> the
#   Link 5: https://ramsey.net/ -> (e.g.
#   Link 6: https://ramsey.net/ -> (e.g.
# Time taken to parse HTML Page 43: 0.0010 seconds
#
# HTML Page 44:
# Title: observations on the role of Engineer, structural
# Number of links: 6
#   Link 1: https://mora.com/ -> that
#   Link 2: https://mora.com/ -> that
#   Link 3: http://www.robbins.com/ -> of
#   Link 4: http://www.robbins.com/ -> of
#   Link 5: http://stevens.org/ -> in
#   Link 6: http://stevens.org/ -> in
# Time taken to parse HTML Page 44: 0.0020 seconds
#
# HTML Page 45:
# Title: observations on the role of Engineer, control and instrumentation
# Number of links: 4
#   Link 1: http://christian-rosales.com/ -> sentences
#   Link 2: http://www.campbell.com/ -> is
#   Link 3: http://www.campbell.com/ -> is
#   Link 4: https://trevino.org/ -> determines
# Time taken to parse HTML Page 45: 0.0021 seconds
#
# HTML Page 46:
# Title: observations on the role of Occupational therapist
# Number of links: 3
#   Link 1: http://www.page-cook.net/ -> descriptively
#   Link 2: https://mendoza.com/ -> sort
#   Link 3: https://www.ryan.com/ -> have
# Time taken to parse HTML Page 46: 0.0010 seconds
#
# HTML Page 47:
# Title: observations on the role of Oncologist
# Number of links: 4
#   Link 1: https://lam.com/ -> for
#   Link 2: https://lam.com/ -> for
#   Link 3: http://castillo-davidson.com/ -> this
#   Link 4: https://peterson.com/ -> eliminate
# Time taken to parse HTML Page 47: 0.0020 seconds
#
# HTML Page 48:
# Title: observations on the role of Publishing copy
# Number of links: 4
#   Link 1: https://www.myers-smith.net/ -> delimits
#   Link 2: https://mccoy.com/ -> account
#   Link 3: http://mcdonald-ford.net/ -> the
#   Link 4: http://mcdonald-ford.net/ -> the
# Time taken to parse HTML Page 48: 0.0010 seconds
#
# HTML Page 49:
# Title: observations on the role of Print production planner
# Number of links: 4
#   Link 1: https://moore.com/ -> in
#   Link 2: https://moore.com/ -> in
#   Link 3: http://www.young-salazar.com/ -> these
# various
#   Link 4: http://gibson-faulkner.com/ -> remedy
# Time taken to parse HTML Page 49: 0.0020 seconds
#
# HTML Page 50:
# Title: observations on the role of Veterinary surgeon
# Number of links: 3
#   Link 1: http://www.mcclure.com/ -> considered
#   Link 2: http://www.roberts.com/ -> suffices
#   Link 3: http://www.medina.com/ -> descriptive
# Time taken to parse HTML Page 50: 0.0020 seconds
#
# HTML Page 51:
# Title: observations on the role of Colour technologist
# Number of links: 4
#   Link 1: http://skinner.com/ -> strong
#   Link 2: https://carpenter.com/ -> distinctive
#   Link 3: http://miller-ferguson.com/ -> of
#   Link 4: http://miller-ferguson.com/ -> of
# Time taken to parse HTML Page 51: 0.0011 seconds
#
# HTML Page 52:
# Title: observations on the role of Civil engineer, consulting
# Number of links: 4
#   Link 1: http://nelson.com/ -> Nevertheless,
#   Link 2: http://www.arias.com/ -> that
#   Link 3: https://www.patel.biz/ -> is
#   Link 4: https://www.patel.biz/ -> is
# Time taken to parse HTML Page 52: 0.0020 seconds
#
# HTML Page 53:
# Title: observations on the role of Outdoor activities/education manager
# Number of links: 5
#   Link 1: http://www.sullivan-delacruz.com/ -> the
#   Link 2: http://www.sullivan-delacruz.com/ -> the
#   Link 3: https://www.owen.com/ -> the
#   Link 4: https://www.owen.com/ -> the
#   Link 5: https://www.parker-murray.com/ -> regarded
# as
# Time taken to parse HTML Page 53: 0.0020 seconds
#
# HTML Page 54:
# Title: observations on the role of Occupational hygienist
# Number of links: 3
#   Link 1: http://coleman.com/ -> important
#   Link 2: https://www.rodriguez.com/ -> system
#   Link 3: http://www.porter.org/ -> linguistic
# Time taken to parse HTML Page 54: 0.0020 seconds
#
# HTML Page 55:
# Title: observations on the role of Radiographer, therapeutic
# Number of links: 4
#   Link 1: http://hernandez.com/ -> an
# important
#   Link 2: https://www.page.net/ -> in
#   Link 3: https://www.page.net/ -> in
#   Link 4: http://hobbs-young.com/ -> respect
# to
# Time taken to parse HTML Page 55: 0.0010 seconds
#
# HTML Page 56:
# Title: observations on the role of Broadcast engineer
# Number of links: 4
#   Link 1: https://sheppard.info/ -> impose
#   Link 2: https://www.smith.com/ -> the
#   Link 3: https://www.smith.com/ -> the
#   Link 4: http://www.griffith-williams.net/ -> defined
# Time taken to parse HTML Page 56: 0.0020 seconds
#
# HTML Page 57:
# Title: observations on the role of Lexicographer
# Number of links: 3
#   Link 1: https://www.carpenter.org/ -> feature
#   Link 2: https://www.stewart-levy.com/ -> paired
#   Link 3: http://www.wallace.net/ -> proposed
# Time taken to parse HTML Page 57: 0.0021 seconds
#
# HTML Page 58:
# Title: observations on the role of Primary school teacher
# Number of links: 5
#   Link 1: https://www.archer.com/ -> of
#   Link 2: https://www.archer.com/ -> of
#   Link 3: http://www.brown.net/ -> to
#   Link 4: http://www.brown.net/ -> to
#   Link 5: http://bryan-evans.biz/ -> underlying
# Time taken to parse HTML Page 58: 0.0020 seconds
#
# HTML Page 59:
# Title: observations on the role of Biomedical engineer
# Number of links: 6
#   Link 1: https://www.hamilton.com/ -> the
#   Link 2: https://www.hamilton.com/ -> the
#   Link 3: http://vasquez.com/ -> is
#   Link 4: http://vasquez.com/ -> is
#   Link 5: https://ortiz-johnson.com/ -> On
#   Link 6: https://ortiz-johnson.com/ -> On
# Time taken to parse HTML Page 59: 0.0040 seconds
#
# HTML Page 60:
# Title: observations on the role of Dealer
# Number of links: 3
#   Link 1: http://singleton-garcia.com/ -> will
#   Link 2: http://www.yoder-ruiz.biz/ -> this
#   Link 3: http://green.biz/ -> underlying
# Time taken to parse HTML Page 60: 0.0031 seconds
#
# HTML Page 61:
# Title: observations on the role of Sales executive
# Number of links: 3
#   Link 1: http://www.mccarty-norris.org/ -> that
#   Link 2: https://www.moore.com/ -> results
#   Link 3: http://lopez.com/ -> language
# Time taken to parse HTML Page 61: 0.0030 seconds
#
# HTML Page 62:
# Title: observations on the role of Psychiatrist
# Number of links: 4
#   Link 1: https://davis-jones.net/ -> suffices
#   Link 2: https://www.davis.com/ -> capacity
#   Link 3: http://www.fernandez.com/ -> of
#   Link 4: http://www.fernandez.com/ -> of
# Time taken to parse HTML Page 62: 0.0020 seconds
#
# HTML Page 63:
# Title: observations on the role of Engineer, land
# Number of links: 5
#   Link 1: http://mcmillan-martinez.com/ -> results
#   Link 2: http://miller.com/ -> the
#   Link 3: http://miller.com/ -> the
#   Link 4: https://www.williams-davis.com/ -> a
#   Link 5: https://www.williams-davis.com/ -> a
# Time taken to parse HTML Page 63: 0.0040 seconds
#
# HTML Page 64:
# Title: observations on the role of Chartered certified accountant
# Number of links: 4
#   Link 1: https://moore-haas.org/ -> be
#   Link 2: https://www.hanson.com/ -> provide
#   Link 3: https://byrd.com/ -> the
#   Link 4: https://byrd.com/ -> the
# Time taken to parse HTML Page 64: 0.0021 seconds
#
# HTML Page 65:
# Title: observations on the role of Engineer, manufacturing systems
# Number of links: 4
#   Link 1: http://walker.org/ -> seen
#   Link 2: http://allison-clark.com/ -> a
#   Link 3: http://allison-clark.com/ -> a
#   Link 4: https://www.sims.info/ -> parasitic
# Time taken to parse HTML Page 65: 0.0030 seconds
#
# HTML Page 66:
# Title: observations on the role of Cabin crew
# Number of links: 3
#   Link 1: https://smith-chase.net/ -> not
#   Link 2: https://singleton.com/ -> power
#   Link 3: http://www.williams.com/ -> theory.
# Time taken to parse HTML Page 66: 0.0010 seconds
#
# HTML Page 67:
# Title: observations on the role of International aid/development worker
# Number of links: 3
#   Link 1: http://www.lawrence-payne.net/ -> connection
#   Link 2: http://saunders.com/ -> gaps
#   Link 3: https://graves.com/ -> closely
# Time taken to parse HTML Page 67: 0.0030 seconds
#
# HTML Page 68:
# Title: observations on the role of Research officer, trade union
# Number of links: 5
#   Link 1: https://mcguire.biz/ -> the
#   Link 2: https://mcguire.biz/ -> the
#   Link 3: http://www.olson.com/ -> an
#   Link 4: http://www.olson.com/ -> an
#   Link 5: http://www.calderon.com/ -> subset
# Time taken to parse HTML Page 68: 0.0021 seconds
#
# HTML Page 69:
# Title: observations on the role of Purchasing manager
# Number of links: 6
#   Link 1: https://www.adams.biz/ -> is
#   Link 2: https://www.adams.biz/ -> is
#   Link 3: https://www.mason.net/ -> the
#   Link 4: https://www.mason.net/ -> the
#   Link 5: http://www.kemp.info/ -> in
#   Link 6: http://www.kemp.info/ -> in
# Time taken to parse HTML Page 69: 0.0030 seconds
#
# HTML Page 70:
# Title: observations on the role of Corporate treasurer
# Number of links: 4
#   Link 1: https://www.vaughn.com/ -> distinctive
#   Link 2: http://www.smith.org/ -> an
#   Link 3: http://www.smith.org/ -> an
#   Link 4: http://nash-harris.com/ -> discussed
# Time taken to parse HTML Page 70: 0.0010 seconds
#
# HTML Page 71:
# Title: observations on the role of Tax adviser
# Number of links: 4
#   Link 1: http://hughes.com/ -> of
#   Link 2: http://hughes.com/ -> of
#   Link 3: http://marquez.com/ -> different
#   Link 4: http://day.info/ -> apparently,
# determined
# Time taken to parse HTML Page 71: 0.0020 seconds
#
# HTML Page 72:
# Title: observations on the role of Human resources officer
# Number of links: 5
#   Link 1: http://www.french.com/ -> with
#   Link 2: http://www.french.com/ -> with
#   Link 3: http://green.org/ -> I
#   Link 4: https://www.johnson.com/ -> not
#   Link 5: https://www.johnson.com/ -> not
# Time taken to parse HTML Page 72: 0.0020 seconds
#
# HTML Page 73:
# Title: observations on the role of Health visitor
# Number of links: 3
#   Link 1: http://www.barker.com/ -> We
#   Link 2: https://www.freeman-martin.com/ -> may
# remedy
#   Link 3: http://gates.net/ -> linguistics
# Time taken to parse HTML Page 73: 0.0021 seconds
#
# HTML Page 74:
# Title: observations on the role of Surveyor, planning and development
# Number of links: 5
#   Link 1: https://www.clark.com/ -> to
#   Link 2: https://www.clark.com/ -> to
#   Link 3: http://www.delacruz-robinson.info/ -> we
#   Link 4: https://harris.org/ -> a
#   Link 5: https://harris.org/ -> a
# Time taken to parse HTML Page 74: 0.0020 seconds
#
# HTML Page 75:
# Title: observations on the role of Therapist, music
# Number of links: 4
#   Link 1: http://davis.com/ -> levels
#   Link 2: https://joseph-poole.com/ -> the
#   Link 3: https://joseph-poole.com/ -> the
#   Link 4: http://www.freeman.com/ -> Of
# Time taken to parse HTML Page 75: 0.0020 seconds
#
# HTML Page 76:
# Title: observations on the role of Textile designer
# Number of links: 3
#   Link 1: http://hammond.com/ -> does
#   Link 2: https://gardner-martinez.net/ -> selectionally
#   Link 3: https://www.snow.com/ -> Summarizing,
# Time taken to parse HTML Page 76: 0.0020 seconds
#
# HTML Page 77:
# Title: observations on the role of Administrator, education
# Number of links: 5
#   Link 1: https://cook.com/ -> the
#   Link 2: https://cook.com/ -> the
#   Link 3: http://cook.org/ -> that
#   Link 4: http://cook.org/ -> that
#   Link 5: http://www.baker-howell.biz/ -> functional
# Time taken to parse HTML Page 77: 0.0020 seconds
#
# HTML Page 78:
# Title: observations on the role of Analytical chemist
# Number of links: 4
#   Link 1: http://www.hutchinson.net/ -> constructions
#   Link 2: https://proctor.org/ -> the
#   Link 3: https://proctor.org/ -> the
#   Link 4: http://www.maddox.com/ -> descriptively
# Time taken to parse HTML Page 78: 0.0021 seconds
#
# HTML Page 79:
# Title: observations on the role of Garment/textile technologist
# Number of links: 3
#   Link 1: http://www.chung.com/ -> T(Z,K),
#   Link 2: https://www.singh.info/ -> contexts
#   Link 3: http://www.hodges.com/ -> modern
# Time taken to parse HTML Page 79: 0.0020 seconds
#
# HTML Page 80:
# Title: observations on the role of Learning mentor
# Number of links: 3
#   Link 1: https://www.green.net/ -> gibberish
#   Link 2: https://www.wright.biz/ -> at
# the
#   Link 3: https://potter.com/ -> same
# Time taken to parse HTML Page 80: 0.0010 seconds
#
# HTML Page 81:
# Title: observations on the role of Multimedia programmer
# Number of links: 3
#   Link 1: https://lowery.com/ -> distinctive
#   Link 2: https://sellers.biz/ -> way
#   Link 3: https://lee-gray.info/ -> appearance
# of
# Time taken to parse HTML Page 81: 0.0020 seconds
#
# HTML Page 82:
# Title: observations on the role of Local government officer
# Number of links: 4
#   Link 1: https://www.boyer-jones.com/ -> an
#   Link 2: https://www.boyer-jones.com/ -> an
#   Link 3: https://www.hayes.biz/ -> instance,
#   Link 4: http://holder.info/ -> functional
# Time taken to parse HTML Page 82: 0.0020 seconds
#
# HTML Page 83:
# Title: observations on the role of Designer, ceramics/pottery
# Number of links: 3
#   Link 1: https://www.jones.com/ -> distinction
#   Link 2: https://macdonald.com/ -> developed
#   Link 3: http://www.bailey.org/ -> correlate
# Time taken to parse HTML Page 83: 0.0010 seconds
#
# HTML Page 84:
# Title: observations on the role of Financial trader
# Number of links: 4
#   Link 1: http://wu.com/ -> constructions
#   Link 2: https://moody.com/ -> to
#   Link 3: https://moody.com/ -> to
#   Link 4: http://johnson.net/ -> grounds
# Time taken to parse HTML Page 84: 0.0021 seconds
#
# HTML Page 85:
# Title: observations on the role of Scientist, physiological
# Number of links: 4
#   Link 1: https://www.palmer-turner.com/ -> these
#   Link 2: https://www.smith.com/ -> dominance
#   Link 3: http://www.aguilar.org/ -> not
#   Link 4: http://www.aguilar.org/ -> not
# Time taken to parse HTML Page 85: 0.0010 seconds
#
# HTML Page 86:
# Title: observations on the role of Paediatric nurse
# Number of links: 3
#   Link 1: http://gonzalez.info/ -> grammar.
#   Link 2: http://jones-brown.info/ -> this
#   Link 3: http://gordon-hall.biz/ -> standard
# Time taken to parse HTML Page 86: 0.0020 seconds
#
# HTML Page 87:
# Title: observations on the role of Transport planner
# Number of links: 4
#   Link 1: https://www.beck-hall.com/ -> certain
#   Link 2: https://campbell.info/ -> of
#   Link 3: https://campbell.info/ -> of
#   Link 4: https://howell.biz/ -> any
# Time taken to parse HTML Page 87: 0.0030 seconds
#
# HTML Page 88:
# Title: observations on the role of Geoscientist
# Number of links: 4
#   Link 1: https://www.pope.com/ -> to
#   Link 2: https://www.pope.com/ -> to
#   Link 3: http://www.munoz.com/ -> various
#   Link 4: https://www.hamilton.com/ -> the
# theory.
# Time taken to parse HTML Page 88: 0.0020 seconds
#
# HTML Page 89:
# Title: observations on the role of Automotive engineer
# Number of links: 5
#   Link 1: http://oconnor.com/ -> in
#   Link 2: http://oconnor.com/ -> in
#   Link 3: http://www.fritz-franklin.net/ -> that
#   Link 4: http://www.fritz-franklin.net/ -> that
#   Link 5: https://www.jones-jones.net/ -> nondistinctness
# Time taken to parse HTML Page 89: 0.0021 seconds
#
# HTML Page 90:
# Title: observations on the role of Careers adviser
# Number of links: 5
#   Link 1: https://www.lopez.com/ -> in
#   Link 2: https://www.lopez.com/ -> in
#   Link 3: https://hernandez.com/ -> speaker-hearer's
#   Link 4: https://campbell.com/ -> is
#   Link 5: https://campbell.com/ -> is
# Time taken to parse HTML Page 90: 0.0020 seconds
#
# HTML Page 91:
# Title: observations on the role of Designer, graphic
# Number of links: 3
#   Link 1: http://nguyen.com/ -> test.
#   Link 2: http://jenkins.info/ -> sets
#   Link 3: http://torres.com/ -> underlying
# Time taken to parse HTML Page 91: 0.0020 seconds
#
# HTML Page 92:
# Title: observations on the role of Games developer
# Number of links: 3
#   Link 1: https://tate.com/ -> (96)
# and
#   Link 2: https://www.leach.net/ -> It
#   Link 3: http://baker.net/ -> certain
# Time taken to parse HTML Page 92: 0.0010 seconds
#
# HTML Page 93:
# Title: observations on the role of Chartered certified accountant
# Number of links: 5
#   Link 1: https://chavez.com/ -> in
#   Link 2: https://chavez.com/ -> in
#   Link 3: https://www.velazquez.com/ -> interpretation
#   Link 4: https://www.andrews.com/ -> a
#   Link 5: https://www.andrews.com/ -> a
# Time taken to parse HTML Page 93: 0.0020 seconds
#
# HTML Page 94:
# Title: observations on the role of Fine artist
# Number of links: 5
#   Link 1: http://castro.com/ -> (e.g.
#   Link 2: http://castro.com/ -> (e.g.
#   Link 3: https://shaw.info/ -> selectional
#   Link 4: https://www.carter.com/ -> for
#   Link 5: https://www.carter.com/ -> for
# Time taken to parse HTML Page 94: 0.0024 seconds
#
# HTML Page 95:
# Title: observations on the role of Secretary, company
# Number of links: 5
#   Link 1: http://garrett.com/ -> in
#   Link 2: http://garrett.com/ -> in
#   Link 3: https://cox.com/ -> appears
#   Link 4: https://cox.com/ -> appears
#   Link 5: https://brady-palmer.com/ -> discussion
# Time taken to parse HTML Page 95: 0.0020 seconds
#
# HTML Page 96:
# Title: observations on the role of Production assistant, television
# Number of links: 3
#   Link 1: https://www.montgomery.com/ -> equivalent
#   Link 2: https://edwards-key.com/ -> morphological
#   Link 3: http://garcia-terry.com/ -> most
# Time taken to parse HTML Page 96: 0.0020 seconds
#
# HTML Page 97:
# Title: observations on the role of Sports therapist
# Number of links: 5
#   Link 1: https://www.martinez.com/ -> information
#   Link 2: http://anderson.org/ -> of
#   Link 3: http://anderson.org/ -> of
#   Link 4: http://www.pearson.info/ -> one
#   Link 5: http://www.pearson.info/ -> one
# Time taken to parse HTML Page 97: 0.0020 seconds
#
# HTML Page 98:
# Title: observations on the role of Art therapist
# Number of links: 5
#   Link 1: http://scott-smith.net/ -> be
#   Link 2: http://scott-smith.net/ -> be
#   Link 3: http://www.lambert.net/ -> (98d)).
#   Link 4: http://hamilton-russell.com/ -> that
#   Link 5: http://hamilton-russell.com/ -> that
# Time taken to parse HTML Page 98: 0.0010 seconds
#
# HTML Page 99:
# Title: observations on the role of Sports therapist
# Number of links: 5
#   Link 1: https://www.davis.com/ -> system
#   Link 2: http://www.davis.com/ -> the
#   Link 3: http://www.davis.com/ -> the
#   Link 4: http://martinez-reeves.com/ -> the
#   Link 5: http://martinez-reeves.com/ -> the
# Time taken to parse HTML Page 99: 0.0020 seconds
#
# HTML Page 100:
# Title: observations on the role of Sports coach
# Number of links: 4
#   Link 1: https://morgan.org/ -> rules.
#   Link 2: http://reed-mcbride.com/ -> notion
#   Link 3: https://yang-johnson.net/ -> a
#   Link 4: https://yang-johnson.net/ -> a
# Time taken to parse HTML Page 100: 0.0021 seconds
#
# HTML Page 101:
# Title: observations on the role of Chief Operating Officer
# Number of links: 3
#   Link 1: https://wilson.com/ -> an
# interpretation
#   Link 2: https://duran-monroe.com/ -> different
#   Link 3: http://www.hall.com/ -> (99a))
# Time taken to parse HTML Page 101: 0.0010 seconds
#
# HTML Page 102:
# Title: observations on the role of Seismic interpreter
# Number of links: 4
#   Link 1: http://www.trevino.com/ -> sort
#   Link 2: http://higgins.net/ -> the
#   Link 3: http://higgins.net/ -> the
#   Link 4: http://morales-cardenas.info/ -> the
# constructions
# Time taken to parse HTML Page 102: 0.0020 seconds
#
# HTML Page 103:
# Title: observations on the role of Press photographer
# Number of links: 3
#   Link 1: http://herrera.org/ -> fundamental
# error
#   Link 2: http://scott-andersen.com/ -> distinctive
# feature
#   Link 3: https://www.obrien.com/ -> has
# Time taken to parse HTML Page 103: 0.0040 seconds
#
# HTML Page 104:
# Title: observations on the role of Lobbyist
# Number of links: 3
#   Link 1: https://stewart.com/ -> delimits
#   Link 2: https://www.dodson-brown.org/ -> feature
# theory.
#   Link 3: http://barnes.com/ -> resumptive
# Time taken to parse HTML Page 104: 0.0030 seconds
#
# HTML Page 105:
# Title: observations on the role of Engineer, maintenance (IT)
# Number of links: 5
#   Link 1: https://kelley.net/ -> to
#   Link 2: https://kelley.net/ -> to
#   Link 3: https://www.bass.com/ -> grammarians.
#   Link 4: https://www.johnson.net/ -> the
#   Link 5: https://www.johnson.net/ -> the
# Time taken to parse HTML Page 105: 0.0030 seconds
#
# HTML Page 106:
# Title: observations on the role of Psychotherapist, dance movement
# Number of links: 4
#   Link 1: https://morris-smith.com/ -> general
#   Link 2: http://prince.org/ -> Thus
#   Link 3: https://le-underwood.com/ -> in
#   Link 4: https://le-underwood.com/ -> in
# Time taken to parse HTML Page 106: 0.0030 seconds
#
# HTML Page 107:
# Title: observations on the role of Surgeon
# Number of links: 3
#   Link 1: http://salazar.com/ -> various
#   Link 2: http://kerr-contreras.com/ -> (96)
#   Link 3: http://www.ellis.info/ -> By
# Time taken to parse HTML Page 107: 0.0030 seconds
#
# HTML Page 108:
# Title: observations on the role of Logistics and distribution manager
# Number of links: 3
#   Link 1: https://martinez.com/ -> into
#   Link 2: https://www.hill.com/ -> rather
#   Link 3: http://www.salazar-brown.com/ -> theory.
# Time taken to parse HTML Page 108: 0.0050 seconds
#
# HTML Page 109:
# Title: observations on the role of Higher education lecturer
# Number of links: 3
#   Link 1: http://www.nash.com/ -> the
# forms
#   Link 2: https://www.estrada-sanchez.info/ -> domains
#   Link 3: http://smith.info/ -> use.
# Time taken to parse HTML Page 109: 0.0050 seconds
#
# HTML Page 110:
# Title: observations on the role of Cabin crew
# Number of links: 4
#   Link 1: http://smith.com/ -> stipulation
#   Link 2: https://phillips-rivera.org/ -> just
#   Link 3: http://www.smith.com/ -> which
#   Link 4: http://www.smith.com/ -> which
# Time taken to parse HTML Page 110: 0.0040 seconds
#
# HTML Page 111:
# Title: observations on the role of Museum/gallery conservator
# Number of links: 4
#   Link 1: http://williams-taylor.com/ -> general
#   Link 2: http://williams-taylor.com/ -> general
#   Link 3: https://holden.com/ -> since
#   Link 4: http://www.short.com/ -> respect
# Time taken to parse HTML Page 111: 0.0030 seconds
#
# HTML Page 112:
# Title: observations on the role of Theatre director
# Number of links: 3
#   Link 1: http://manning.net/ -> English
#   Link 2: https://www.sims-lee.org/ -> seen
#   Link 3: https://www.jones.com/ -> theory.
# Time taken to parse HTML Page 112: 0.0052 seconds
#
# HTML Page 113:
# Title: observations on the role of Geologist, engineering
# Number of links: 5
#   Link 1: http://riley-armstrong.biz/ -> that
#   Link 2: http://riley-armstrong.biz/ -> that
#   Link 3: https://weaver.com/ -> the
#   Link 4: https://weaver.com/ -> the
#   Link 5: http://www.sullivan.com/ -> high
# Time taken to parse HTML Page 113: 0.0030 seconds
#
# HTML Page 114:
# Title: observations on the role of Garment/textile technologist
# Number of links: 4
#   Link 1: https://alvarez.com/ -> of
#   Link 2: https://alvarez.com/ -> of
#   Link 3: https://www.ward.net/ -> branching
#   Link 4: https://www.robinson-green.com/ -> of
# parasitic
# Time taken to parse HTML Page 114: 0.0010 seconds
#
# HTML Page 115:
# Title: observations on the role of Ecologist
# Number of links: 4
#   Link 1: https://hernandez.com/ -> It
#   Link 2: https://hernandez.com/ -> It
#   Link 3: https://rich.biz/ -> corpus
#   Link 4: http://www.lewis.org/ -> earlier
# Time taken to parse HTML Page 115: 0.0030 seconds
#
# HTML Page 116:
# Title: observations on the role of Psychiatric nurse
# Number of links: 4
#   Link 1: http://www.avila.com/ -> as
#   Link 2: http://www.avila.com/ -> as
#   Link 3: http://carpenter-carter.biz/ -> stipulation
#   Link 4: http://www.smith-walker.com/ -> underlying
# order.
# Time taken to parse HTML Page 116: 0.0021 seconds
#
# HTML Page 117:
# Title: observations on the role of Public affairs consultant
# Number of links: 5
#   Link 1: http://dillon.com/ -> to
#   Link 2: http://dillon.com/ -> to
#   Link 3: http://walker.com/ -> apparently,
#   Link 4: http://www.steele.com/ -> an
#   Link 5: http://www.steele.com/ -> an
# Time taken to parse HTML Page 117: 0.0020 seconds
#
# HTML Page 118:
# Title: observations on the role of Hydrogeologist
# Number of links: 4
#   Link 1: https://www.terry.com/ -> an
#   Link 2: https://www.terry.com/ -> an
#   Link 3: https://www.parker-ruiz.com/ -> intuition
#   Link 4: https://www.wong.com/ -> language
# Time taken to parse HTML Page 118: 0.0020 seconds
#
# HTML Page 119:
# Title: observations on the role of Plant breeder/geneticist
# Number of links: 4
#   Link 1: http://www.barrera.com/ -> application
#   Link 2: https://stout-mclaughlin.com/ -> an
# interpretation
#   Link 3: http://www.scott.com/ -> the
#   Link 4: http://www.scott.com/ -> the
# Time taken to parse HTML Page 119: 0.0020 seconds
#
# HTML Page 120:
# Title: observations on the role of Buyer, retail
# Number of links: 5
#   Link 1: https://fletcher.info/ -> of
#   Link 2: https://fletcher.info/ -> of
#   Link 3: http://houston.com/ -> the
#   Link 4: http://houston.com/ -> the
#   Link 5: http://davis.biz/ -> unspecified
# Time taken to parse HTML Page 120: 0.0010 seconds
#
# HTML Page 121:
# Title: observations on the role of Writer
# Number of links: 3
#   Link 1: https://www.palmer.com/ -> A
#   Link 2: https://ruiz.org/ -> Nevertheless,
# this
#   Link 3: http://fowler.com/ -> gibberish
# Time taken to parse HTML Page 121: 0.0020 seconds
#
# HTML Page 122:
# Title: observations on the role of Engineer, land
# Number of links: 3
#   Link 1: https://www.nixon.org/ -> delimits
#   Link 2: https://vazquez-weaver.com/ -> construction.
#   Link 3: https://brown.com/ -> On
# Time taken to parse HTML Page 122: 0.0010 seconds
#
# HTML Page 123:
# Title: observations on the role of Training and development officer
# Number of links: 4
#   Link 1: https://www.ingram-underwood.net/ -> supporting
# element
#   Link 2: http://www.richard-jackson.com/ -> is
#   Link 3: http://www.richard-jackson.com/ -> is
#   Link 4: https://perez.com/ -> developed
# Time taken to parse HTML Page 123: 0.0010 seconds
#
# HTML Page 124:
# Title: observations on the role of Scientist, product/process development
# Number of links: 3
#   Link 1: https://www.brown.com/ -> introduced
#   Link 2: http://davis.org/ -> feature
#   Link 3: https://www.schaefer.com/ -> determines
# Time taken to parse HTML Page 124: 0.0010 seconds
#
# HTML Page 125:
# Title: observations on the role of Teacher, secondary school
# Number of links: 4
#   Link 1: http://glover-joseph.info/ -> deformations,
#   Link 2: http://lyons.net/ -> regarded
#   Link 3: https://www.cummings-hodges.com/ -> in
#   Link 4: https://www.cummings-hodges.com/ -> in
# Time taken to parse HTML Page 125: 0.0020 seconds
#
# Total time taken for the entire process: 0.7699 seconds
